# %% [markdown]
# <a href="https://colab.research.google.com/github/Badruzaman/BinaryTree/blob/master/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for item in range(5):
  print(item)
  print('hello')
# Out:
# 0
# hello
# 1
# hello
# 2
# hello
# 3
# hello
# 4
# hello
